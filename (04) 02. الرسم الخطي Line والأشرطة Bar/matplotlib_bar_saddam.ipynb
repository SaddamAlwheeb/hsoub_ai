# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('car_malfunctions.csv')
df
# Out:
#    Age  malfunctions  DaysOff
# 0    5             6       15
# 1   10            10       20
# 2   20            25       50
# 3   25            50      100
# 4   35            75      200
# 5   40            90      240

# %%
plt.plot(df)
# Out:
# [<matplotlib.lines.Line2D at 0x14e9115f740>,
#  <matplotlib.lines.Line2D at 0x14e9087e330>,
#  <matplotlib.lines.Line2D at 0x14e8dde3650>]

# %%
plt.plot(df['Age'],df['malfunctions'])
plt.plot(df['Age'],df['DaysOff'])

# %%
ypoint = df['malfunctions']
plt.plot(ypoint,marker='s')
plt.show()

# %%
df = pd.read_csv('car_malfunctions_2.csv')
df
# Out:
#        Name  Malfunctions
# 0    Toyota            15
# 1       BMW            30
# 2  Mercedes            40
# 3       Kia            55
# 4    Hunday            60

# %%
x = df['Name']
y = df['Malfunctions']

plt.xlabel('Machine')
plt.ylabel('fiaulier')
plt.bar(x,y)
plt.show()

# %%
plt.plot(x,y,marker='o')

# %%
data = [25,15,35,25]

plt.pie(data)
# Out:
# ([<matplotlib.patches.Wedge at 0x14e988580e0>,
#   <matplotlib.patches.Wedge at 0x14e98852060>,
#   <matplotlib.patches.Wedge at 0x14e988db3e0>,
#   <matplotlib.patches.Wedge at 0x14e98876150>],
#  [Text(0.7778174593052024, 0.7778174593052024, ''),
#   Text(-0.4993895680663527, 0.9801071672559598, ''),
#   Text(-0.9801071672559598, -0.49938956806635265, ''),
#   Text(0.7778174593052022, -0.7778174593052025, '')])
